# %% [markdown]
# # Network Graphing
#
# Using networkx to create a network of JQA papers. This notebook follows and copies much from the following tutorial. If this is helpful, cite them:
#
#
# John R. Ladd, Jessica Otis, Christopher N. Warren, and Scott Weingart, "Exploring and Analyzing Network Data with Python," The Programming Historian 6 (2017), https://doi.org/10.46430/phen0064.

# %%
import re
import pandas as pd
import numpy as np
import networkx as nx
from networkx.algorithms import community
from operator import itemgetter

# Declare directory location to shorten filepaths later.
abs_dir = "/Users/quinn.wi/Documents/SemanticData/"

# %% [markdown]
# ## Import Data & Create Graph Object

# %%
# %%time

# Read in nodes and edges.
nodes = pd.read_csv(abs_dir + "Output/Dataframes/Graphs/JQA_Network_correlation/graphLasso_nodes.csv",
                    sep = ',')

edges = pd.read_csv(abs_dir + "Output/Dataframes/Graphs/JQA_Network_correlation/graphLasso_links.csv",
                    sep = ',')

# Create dictionary to map values to codes.
nodes_dictionary = nodes['label'].to_dict()

# Map labels back onto source and target.
edges = edges.replace({'source':nodes_dictionary, 'target':nodes_dictionary})

# Convert edges dataframe to edges tuple (compatible with graph object below).
edges = [tuple(x) for x in edges[['source', 'target']].to_numpy()]

# Initialize graph object.
G = nx.Graph()

# Add nodes and edges to graph object.
G.add_nodes_from(nodes['label'])
G.add_edges_from(edges)

print (nx.info(G))
# Out:
# Name:
# Type: Graph
# Number of nodes: 5135
# Number of edges: 4406
# Average degree:   1.7161
# CPU times: user 555 ms, sys: 12.4 ms, total: 568 ms
# Wall time: 572 ms

# %% [markdown]
# ## Network Measurements
#
# ### Network Density
#
# Network density is measured on a scale from 0 (sparse) to 1 (dense). From Ladd et. al,
#
#     "A 0 would mean that there are no connections at all, and a 1 would indicate that all
#     possible edges are present (a perfectly connected network)"
#
# #### Subcomponents
# Subgraphs (sub-components of a graph) can express the density of networks that are not connected or have decentralized structures.
#
# #### Triadic Closure
# Similarly, triadic closure articulates network interconnectedness but through inferred connections (if one entity relates to two other entities, who are not directly related, then it can be inferred that all three share a relationship). Triadic closure (transitivity) is the ratio of all actual connections over possible connections (nodes^2?).

# %%
# %%time

# Measure network density.
density = nx.density(G)
print ("Network density:", density)

# Related to diameter, check if network is connected and, therefore, can have a diameter.
print ("Is the network connected?", nx.is_connected(G))

# Get a list of network components (communities).
# Find the largest component.
components = nx.connected_components(G)
largest_component = max(components, key = len)

# Create a subgraph of the largest component and measure its diameter.
subgraph = G.subgraph(largest_component)
diameter = nx.diameter(subgraph)
print ("Network diameter of the largest component:", diameter)

# Find triadic closure (similar to density).
triadic_closure = nx.transitivity(G)
print ("Triadic closure:", triadic_closure)
# Out:
# Network density: 0.0003342552030130004
# Is the network connected? False
# Network diameter of the largest component: 1
# Triadic closure: 1.0
# CPU times: user 83.9 ms, sys: 2.37 ms, total: 86.2 ms
# Wall time: 85.4 ms

# %% [markdown]
# ### Centrality
#
# Centrality refers to various methods used to determine the importance of nodes in a graph.
#
# #### Degree
# One measure of centrality is to find each node's degree. The degree of a node is the sum of all its edges. If a node links to three other entities, then its degree is three. A node with a high degree is considered a hub or spoke.

# %%
# %%time

# Create a dictionary of each nodes degree.
degree_dict = dict(G.degree(G.nodes()))
nx.set_node_attributes(G, degree_dict, 'degree')

# Sort nodes by degree and print top results.
sorted_degree = sorted(degree_dict.items(), key = itemgetter(1), reverse = True)
print ("Top 20 nodes by degree:")
for d in sorted_degree[:20]:
    print (d)
# Out:
# Top 20 nodes by degree:
# ('bonaparte-charles', 12)
# ('browne-peter', 12)
# ('calvert-george3', 12)
# ('gerard-conrad', 12)
# ('haviland-john', 12)
# ('kneller-godfrey', 12)
# ('mcneal-unknown2', 12)
# ('peale-charles', 12)
# ('peale-titian', 12)
# ('peters-unknown4', 12)
# ('philippon-unknown', 12)
# ('vandyke-anthony', 12)
# ('wheldon-wilmon', 12)
# ('caton-unknown', 11)
# ('clapp-asa', 11)
# ('elder-unknown', 11)
# ('hone-unknown2', 11)
# ('moseby-unknown', 11)
# ('oliver-unknown', 11)
# ('proctor-unkown', 11)
# CPU times: user 6.35 ms, sys: 295 µs, total: 6.65 ms
# Wall time: 6.52 ms

# %% [markdown]
# #### Betweenness Centrality
#
# While degree privileges the nodes with the most direct connections, some nodes might be important because they glue together two different groups. These broker nodes are important because they keep different branches of a network attached.

# %%
# %%time

# Get centrality measurements.
betweenness_dict = nx.betweenness_centrality(G)

# Assign each measuremnt to attributes within the network.
nx.set_node_attributes(G, betweenness_dict, "betweenness")

# Sort and print nodes with high centrality scores.
sorted_betweenness = sorted(betweenness_dict.items(), key = itemgetter(1), reverse = True)

print ("Top 20 nodes by betweenness centrality")
for b in sorted_betweenness[:20]:
    print (b)
# Out:
# Top 20 nodes by betweenness centrality
# ('Ishbosheth', 0.0)
# ('Willis Alston', 0.0)
# ('abbot-benjamin', 0.0)
# ('abbot-joel', 0.0)
# ('abbot-joel2', 0.0)
# ('abbot-joseph', 0.0)
# ('abbot-unknown', 0.0)
# ('abbott-joel', 0.0)
# ('abbott-joseph', 0.0)
# ('abdon', 0.0)
# ('abner', 0.0)
# ('abraham', 0.0)
# ('abram-unknown', 0.0)
# ('absalom', 0.0)
# ('achish', 0.0)
# ('adadms-john', 0.0)
# ('adair-robert', 0.0)
# ('adams-abigail', 0.0)
# ('adams-abigail2', 0.0)
# ('adams-abigail3', 0.0)
# CPU times: user 11.5 s, sys: 54.3 ms, total: 11.6 s
# Wall time: 11.7 s

# %% [markdown]
# #### Eigenvector Centrality
#
# Eigenvector centrality, like degree, considers centrality an aspect of interconnectedness. It also counts node degree. Eigenvector centrality, however, goes a step further and also considers whether a hub is connected to other hubs.

# %%
# %%time

# Get centrality measurements.
eigenvector_dict = nx.eigenvector_centrality(G)

# Assign each measuremnt to attributes within the network.
nx.set_node_attributes(G, eigenvector_dict, "eigenvector")

# Sort and print nodes with high centrality scores.
sorted_eigenvector = sorted(eigenvector_dict.items(), key = itemgetter(1), reverse = True)

print ("Top 20 nodes by eigenvector centrality")
for b in sorted_eigenvector[:20]:
    print (b)
# Out:
# Top 20 nodes by eigenvector centrality
# ('bonaparte-charles', 0.27731903930585705)
# ('browne-peter', 0.27731903930585705)
# ('calvert-george3', 0.27731903930585705)
# ('gerard-conrad', 0.27731903930585705)
# ('haviland-john', 0.27731903930585705)
# ('kneller-godfrey', 0.27731903930585705)
# ('mcneal-unknown2', 0.27731903930585705)
# ('peale-charles', 0.27731903930585705)
# ('peale-titian', 0.27731903930585705)
# ('peters-unknown4', 0.27731903930585705)
# ('philippon-unknown', 0.27731903930585705)
# ('vandyke-anthony', 0.27731903930585705)
# ('wheldon-wilmon', 0.27731903930585705)
# ('caton-unknown', 0.004318671409409538)
# ('clapp-asa', 0.004318671409409538)
# ('elder-unknown', 0.004318671409409538)
# ('hone-unknown2', 0.004318671409409538)
# ('moseby-unknown', 0.004318671409409538)
# ('oliver-unknown', 0.004318671409409538)
# ('proctor-unkown', 0.004318671409409538)
# CPU times: user 360 ms, sys: 3.38 ms, total: 363 ms
# Wall time: 365 ms

# %% [markdown]
# #### Combining Measurements
#
# Often nodes with high degrees will also have high eigenvector or betweenness centrality. But, what if you want to know which of the high eigenvector centrality nodes had low degree?

# %%
# %%time

# Create list of top 20 nodes by eigenvector.
top_eigenvector = sorted_eigenvector[:20]

# Find and print their degrees.
for te in top_eigenvector:
    degree = degree_dict[te[0]]
    print ("Name:", te[0], "| Eigenvector Centrality:", te[1], "| Degree:", degree)
# Out:
# Name: bonaparte-charles | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: browne-peter | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: calvert-george3 | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: gerard-conrad | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: haviland-john | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: kneller-godfrey | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: mcneal-unknown2 | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: peale-charles | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: peale-titian | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: peters-unknown4 | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: philippon-unknown | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: vandyke-anthony | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: wheldon-wilmon | Eigenvector Centrality: 0.27731903930585705 | Degree: 12
# Name: caton-unknown | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# Name: clapp-asa | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# Name: elder-unknown | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# Name: hone-unknown2 | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# Name: moseby-unknown | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# Name: oliver-unknown | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# Name: proctor-unkown | Eigenvector Centrality: 0.004318671409409538 | Degree: 11
# CPU times: user 3.65 ms, sys: 3.08 ms, total: 6.73 ms
# Wall time: 4.24 ms

# %% [markdown]
# ## Community Detection
#
# Community refers to the subgroups that appear within a network.
#
# #### Modularity
#
# Modularity helps discover sub-communities within a network by searching for pockets of nodes with a relatively high density.

# %%
# %%time

# Find communities.
communities = community.greedy_modularity_communities(G)

# Create a dictionary that maps nodes to their community.
modularity_dict = {}
for i, c in enumerate(communities):
    for name in c:
        modularity_dict[name] = i
        
# Add modularity information to graph object.
nx.set_node_attributes(G, modularity_dict, 'modularity')
# Out:
# CPU times: user 182 ms, sys: 4.09 ms, total: 186 ms
# Wall time: 187 ms

# %% [markdown]
# #### Combining Methods
#
# Combining eigenvector centrality as ranking indicates nodes central to each community.

# %%
# %%time

# Examine nodes from first modularity class.
class0 = [n for n in G.nodes() if G.nodes[n]['modularity'] == 0]

# Create dictionary of eigenvector centralities of those nodes.
class0_eig = {n:G.nodes[n]['eigenvector'] for n in class0}

# Sort and print first 5 results.
class0_sorted_eig = sorted(class0_eig.items(), key = itemgetter(1), reverse = True)

print ("Modularity Class 0 Sorted by Eigenvector Centrality:")
for node in class0_sorted_eig[:5]:
    print ("Name:", node[0], "| Eigenvector Centrality:", node[1])
# Out:
# Modularity Class 0 Sorted by Eigenvector Centrality:
# Name: bonaparte-charles | Eigenvector Centrality: 0.27731903930585705
# Name: browne-peter | Eigenvector Centrality: 0.27731903930585705
# Name: calvert-george3 | Eigenvector Centrality: 0.27731903930585705
# Name: gerard-conrad | Eigenvector Centrality: 0.27731903930585705
# Name: haviland-john | Eigenvector Centrality: 0.27731903930585705
# CPU times: user 4.48 ms, sys: 975 µs, total: 5.46 ms
# Wall time: 4.65 ms

# %% [markdown]
# #### Community Membership

# %%
# %%time

for i, c in enumerate(communities):
    if len(c) > 2:
        print ('Class ' + str(i) + ':', list(c), '\n')
# Out:
# Class 0: ['kneller-godfrey', 'bonaparte-charles', 'calvert-george3', 'browne-peter', 'peters-unknown4', 'gerard-conrad', 'peale-charles', 'vandyke-anthony', 'wheldon-wilmon', 'peale-titian', 'haviland-john', 'mcneal-unknown2', 'philippon-unknown']
#
# Class 1: ['rogers-moulton', 'hone-unknown2', 'tyson-unknown', 'proctor-unkown', 'caton-unknown', 'moseby-unknown', 'thompson-unknown8', 'oliver-unknown', 'randall-unknown4', 'elder-unknown', 'scott-unknown7', 'clapp-asa']
#
# Class 2: ['pickman-elizabeth', 'pickman-martha', 'brazer-unknown2', 'rogers-unknown3', 'rogers-unknown2', 'felt-abigail', 'leslie-alexander', 'pickman-anstiss', 'endicott-john', 'adadms-john', 'felt-joseph']
#
# Class 3: ['ellery-abraham', 'magee-unknown', 'dowse-unknown2', 'ellery-sarah', 'hubbard-unknown4', 'ellery-unknown2', 'ellery-unknown3', 'hubbard-unknown5', 'dowse-unknown', 'ellery-martha', 'shaw-unknown2']
#
# Class 4: ['bethune-george', 'adams-abigail3', 'russell-catherine', 'tucker-unknown4', 'bethune-unknown', 'hall-susanna', 'freeman-susan', 'derby-martha', 'howland-unknown3', 'adams-hannah', 'baring-unknown2']
#
# Class 5: ['ferdinand-i', 'biddle-john', 'lacock-unknown2', 'francis2', 'porter-unknown2', 'clinton-dewitt2', 'anderson-a', 'vollen-unknown', 'christian-unknown2', 'taylor-william2', 'duval-edward']
#
# Class 6: ['meyer-unknown3', 'dexter-samuel2', 'adams-daniel', 'selden-e', 'edmiston-unknown2', 'wheelwright-unknown2', 'meyer-unknown4', 'ketchum-unknown', 'cochran-unknown', 'dexter-unknown3', 'jones-unknown6']
#
# Class 7: ['harmony', 'forsyth-clara2', 'fennell-james', 'inchbald-elizabeth', 'newell-unknown', 'lordnorland', 'hathwell-unknown2', 'whitlock-elizabeth', 'solus', 'ladyeleanorirwin', 'jefferson-unknown']
#
# Class 8: ['peel-unknown', 'flint-james', 'bartlett-unknown3', 'flint-jacob', 'prince-unknown', 'perkins-james', 'kilham-daniel', 'holyoke-edward', 'pickman-unknown', 'bentley-william']
#
# Class 9: ['johnson-joseph2', 'mcfarland-john', 'mceuel-unknown', 'baty-unknown', 'bowie-unknown3', 'near-unknown', 'say-thomas', 'breckenridge-unknown2', 'bullus-oscar', 'mitchill-unknown']
#
# Class 10: ['heywood-unknown', 'ives-unknown3', 'grafton-unknown', 'middleton-oliver', 'raymond-unknown', 'maxcy-unknown', 'pierson-unknown2', 'findley-john', 'ward-unknown3', 'ruggles-unknown']
#
# Class 11: ['packard-asa', 'boylston-ward2', 'packard-unknown', 'packard-ann', 'packard-asa2', 'smith-abigail', 'whitmore-unknown', 'packard-ann2', 'packard-frederick', 'rand-unknown']
#
# Class 12: ['coffin-francis', 'thaxter-celia', 'thaxter-betsey', 'whittemore-sophia', 'thaxter-quincy', 'thaxter-anna', 'thaxter-edward', 'coffin-isaac', 'loring-joanna', 'thaxter-unknown']
#
# Class 13: ['adams-peter3', 'adams-mary', 'bass-hannah', 'austin-unknonwn', 'adams-peter2', 'adams-ebenezer2', 'adams-ebenezer', 'adams-josiah', 'hutson-unknown']
#
# Class 14: ['shepherd-unknown', 'polley-unknown2', 'dewolf-unknown6', 'colman-mary', 'miner-unknown', 'chappotin-bridget', 'hall-unknown8', 'perkins-nathaniel', 'hall-unknown9']
#
# Class 15: ['humphrey-charles', 'hammond-unknown5', 'kellogg-charles', 'archer-s', 'stevenson-mary', 'simms-john', 'newell-unknown3', 'singleton-unknown', 'hallock-john']
#
# Class 16: ['bunker-thomas', 'buchanan-susan', 'howard-unknown2', 'sherman-roger', 'stiles-ezra', 'delavan-unknown2', 'law-unknown2', 'green-thomas', 'bunker-unknown']
#
# Class 17: ['quincy-edmund', 'quincy-edmund2', 'torre-miguel', 'quincy-edmund3', 'quincy-john', 'quincy-abigail', 'quincy-maria', 'quincy-anna', 'hancock-john2']
#
# Class 18: ['thumblert-william', 'paxton-charles', 'crommelin-daniel', 'barclay-thomas2', 'thumblert-george', 'grenville-george', 'thumblert-unknown', 'jackson-unknown4', 'townsend-charles']
#
# Class 19: ['keene-unknown', 'trumbull-sarah', 'bird-robert', 'forman-unknown', 'loomis-unknown', 'dunham-unknown', 'jay-peter', 'wheaton-unknown', 'aspinwall-john']
#
# Class 20: ['hyer-unknown', 'cary-unknown', 'williams-unknown2', 'williams-unknown5', 'carey-unknown2', 'swartwout-john', 'bell-charles', 'white-unknown6', 'white-unknown5']
#
# Class 21: ['wood-william', 'plessig-unknown', 'bruxner-george', 'chapman-rebecca', 'sall-unknown', 'biddle-nicholas2', 'cayley-john', 'morris-mary', 'morris-robert']
#
# Class 22: ['bellamy-unknown', 'lafayette-emilie', 'hunter-unknown2', 'tracy-emilie', 'tracy-g', 'denison-unknown', 'stanley-unknown', 'wortley-unknown', 'beckwith-unknown']
#
# Class 23: ['dawes-harrison', 'greenleaf-william', 'greenleaf-richard', 'greenleaf-john2', 'greenleaf-lucy', 'greenleaf-mary2', 'dawes-lucy', 'cranch-richard']
#
# Class 24: ['mallett-sarah', 'earle-unknown', 'patton-unknown', 'potter-unknown2', 'fenner-james', 'mallett-edward', 'fenner-almira', 'fenner-sarah']
#
# Class 25: ['howe-unknown', 'hall-unknown15', 'desousaholstein-pedro', 'reed-unknown3', 'howland-unknown', 'davis-daniel', 'barnard-j', 'nevin-unknown']
#
# Class 26: ['sands-joshua', 'rowan-unknown', 'estil-benjamin', 'findlay-james', 'knight-lydia', 'marable-john', 'findlay-jane', 'estil-patsy']
#
# Class 27: ['shoemaker-unknown2', 'hartley-winchcombe', 'king-miles', 'michal', 'allen-unknown7', 'hartley-unknown', 'shoemaker-david', 'hartley-david']
#
# Class 28: ['harrison-robert2', 'cushman-robert', 'easton-david', 'mcdonald-unknown', 'king-william3', 'easton-sarah', 'stow-baron', 'barnum-unknown']
#
# Class 29: ['magruder-rachel', 'osullivan-john', 'mcevers-unknown', 'mosher-eliza', 'hughes-t', 'tutt-unknown', 'leroy-herman', 'mosher-unknown2']
#
# Class 30: ['girard-unknown3', 'trumbull-faith', 'stone-william2', 'colden-unknown2', 'colden-unknown', 'girard-unknown4', 'vanrensselaer-charlotte', 'vanrensselaer-jeremiah']
#
# Class 31: ['rogers-daniel', 'bailey-unknown2', 'welles-samuel', 'brazer-john', 'pearce-unknown2', 'brazer-unknown3', 'shepherd-unknown3', 'glover-unknown2']
#
# Class 32: ['allen-unknown4', 'bigelow-timothy', 'thomas-isaiah', 'ward-unknown2', 'lincoln-unknown', 'hastings-unknown', 'wesson-unknown', 'gill-unknown']
#
# Class 33: ['hook-unknown', 'clarkson-charlton', 'wieland-christoph', 'powell-unknown', 'dewindt-caroline2', 'ariosto-ludovico', 'boiardo-matteo', 'dewindt-peter']
#
# Class 34: ['kirkpatrick-unknown', 'williamson-unknown5', 'mayhew-jonathan', 'gilchrist-unknown', 'howard-william', 'kirkpatrick-unknown2', 'green-unknown3', 'easton-unknown2']
#
# Class 35: ['rotch-unknown2', 'littlefield-unknown', 'girard-unknown5', 'coffin-unknown3', 'wood-unknown4', 'rogers-unknown5', 'rogers-unknown6', 'dall-unknown']
#
# Class 36: ['wright-unknown2', 'bell-unknown5', 'grant-unknown2', 'dutton-unknown', 'absalom', 'bell-unknown6', 'widow', 'shimei']
#
# Class 37: ['dewolf-unknown3', 'bowers-unknown', 'cushing-william', 'adams-joseph4', 'forbes-ralph', 'gilbert-stuart', 'cushing-hannah']
#
# Class 38: ['adams-ann2', 'adams-mary2', 'adams-john5', 'hobart-susanna', 'adams-elihu', 'adams-thankful', 'adams-john6']
#
# Class 39: ['hall-unknown22', 'conner-david', 'joab', 'abner', 'black-alexander', 'hall-unknown23', 'Ishbosheth']
#
# Class 40: ['amedey-deborah', 'ellery-john', 'amedey-unknown3', 'amedey-unknown2', 'bartley-mordecai', 'morgan-joseph', 'anderson-john']
#
# Class 41: ['parker-marsham', 'harris-unknown3', 'barker-jacob', 'lloyd-unknown2', 'neth-unknown', 'brooke-basil', 'keating-unknown2']
#
# Class 42: ['page-unknown', 'dewolf-unknown4', 'dewolf-unknown5', 'page-unknown2', 'bacon-unknown', 'perry-mary', 'henderson-anna']
#
# Class 43: ['johnson-unknown7', 'johnson-unknown6', 'payne-william', 'payne-unknown', 'cowles-salmon', 'purviance-unknown', 'mcintyre-unknown']
#
# Class 44: ['biddle-jane', 'randall-josiah', 'mumford-gordon', 'blunt-unknown', 'marston-unknown3', 'carre-unknown', 'alden-horatio']
#
# Class 45: ['shaw-jonathan', 'janney-samuel', 'heap-james', 'gibson-uknown2', 'porter-david2', 'heap-samuel', 'mcardle-unknown']
#
# Class 46: ['kohbrann-unknown', 'crawford-nathaniel', 'simmons-unknown', 'crawford-william2', 'simmons-unknown4', 'simmons-unknown2', 'simmons-unknown3']
#
# Class 47: ['nott-unknown', 'hill-aaron', 'kent-william', 'bacon-francis', 'hill-unknown5', 'hill-unknown4', 'smith-w2']
#
# Class 48: ['martin-dubois', 'mayo-unknown', 'sproston-george', 'martin-unknown2', 'martin-unknown3', 'gibbs-unknown3', 'morris-unknown5']
#
# Class 49: ['fitzgerald-unknown', 'proud-john', 'cummins-unknown', 'tappan-unknown2', 'hedge-unknown', 'kittera-unknown', 'paulding-unknown2']
#
# Class 50: ['cosey', 'chitty-joseph', 'reubenglenroy', 'morton-thomas', 'elizabeth-i', 'chalmers-george', 'tristramfickle']
#
# Class 51: ['gibbon-unknown', 'gibbon-unknown2', 'farnham-john', 'vanquickenberg-unknown', 'gonzalez-unknown', 'brown-w2', 'farnham-william']
#
# Class 52: ['prince-william', 'call-jacob', 'hays-samuel', 'mitchell-john3', 'shuck-unknown', 'wall-garret', 'dayton-unknown']
#
# Class 53: ['marschalk-andrew', 'coffin-joshua', 'watkins-george', 'platt-unknown2', 'gardner-gideon', 'platt-unknown', 'dingley-unknown']
#
# Class 54: ['parkman-unknown', 'bailey-unknown', 'keating-unknown', 'wiggan-timothy', 'mcdonough-thomas2', 'jaques-unknown', 'townsend-solomon']
#
# Class 55: ['rankin-unknown', 'wilkin-james', 'baker-elizabeth', 'hunter-isaac', 'baker-unknown7', 'jackson-andrew2', 'webb-nathan']
#
# Class 56: ['williamson-unknown2', 'tyler-unknown4', 'phillips-unknown6', 'clendenin-unknown', 'tyler-royall', 'thomson-unknown', 'phillips-naphtali']
#
# Class 57: ['cummings-jacob', 'pearson-unknown4', 'howe-estes', 'wonderley-unknown', 'wonderley-unknown2', 'pinckney-henry', 'gaston-william']
#
# Class 58: ['walton-brian', 'tacitus', 'bailey-andrew', 'castelli-bartholomaei', 'carroll-unknown4', 'page-unknown3', 'woodside-unknown2']
#
# Class 59: ['campbell-unknown2', 'ibzan', 'barbour-johnson', 'abdon', 'elon', 'jephthan']
#
# Class 60: ['henderson-unknown', 'mason-mary2', 'mason-maria', 'catlett-unknown', 'mason-unknown10', 'mccabe-john']
#
# Class 61: ['murtochdelany', 'frye-nathnaiel', 'bradford-unknown', 'anderson-unknown7', 'appleton-unknown4', 'dehart-unknown']
#
# Class 62: ['marryat-joseph', 'otis-sophia', 'prince-john', 'otis-sally', 'irving-washington', 'joy-j']
#
# Class 63: ['jones-ephraim', 'putter-henry', 'patterson-mary', 'elwyn-unknown', 'burr-unknown', 'bartlett-unknown']
#
# Class 64: ['cowan-unknown', 'mcclausland-margery', 'randall-unknown6', 'reinert-daniel', 'crawford-william3', 'hitchcock-unknown2']
#
# Class 65: ['pierre-john', 'jones-daniel', 'cruzat-manuel', 'hebert-unknown', 'duhamel-unknown', 'reynolds-uknown']
#
# Class 66: ['pinckney-thomas', 'richards-mark', 'deas-fitz', 'deas-william', 'bloomfield-joseph', 'brevard-joseph']
#
# Class 67: ['messer-asa', 'horton-unknown', 'richmond-unknown', 'allen-thomas', 'ives-unknown5', 'potter-elisha']
#
# Class 68: ['ridgate-b', 'bronaugh-unknown2', 'roberdeau-susan2', 'dydenhoven-unknown', 'erwin-james', 'bastien-unknown']
#
# Class 69: ['joseph4', 'sharp-solomon', 'hughes-unknown3', 'boots-unknown', 'eugenia', 'arce-manuel']
#
# Class 70: ['malac', 'sheil-richard', 'hemeya', 'florinda', 'dashkov-andrei', 'freelove']
#
# Class 71: ['carman-unknown', 'chambers-unknown2', 'sherburne-unknown4', 'findlay-john2', 'clap-unknown', 'kauffman-unknown']
#
# Class 72: ['silsbee-nathaniel2', 'prince-unknown2', 'bridge-nathan', 'adams-w', 'haven-unknown', 'hooper-unknown']
#
# Class 73: ['diggory', 'murry-unknown', 'cardenio', 'smith-bridget', 'dennyman-unknown', 'hathwell-unknown']
#
# Class 74: ['smith-unknown9', 'rogers-unknown4', 'perkins-unknown4', 'bache-richard', 'smith-unknown8', 'price-unknown2']
#
# Class 75: ['hardwick-henry', 'gerry-anna', 'robbins-e', 'lunt-unknown', 'lyman-g', 'spear-luther']
#
# Class 76: ['sprague-unknown', 'hall-sarah', 'adams-samuel2', 'breck-unknown', 'king-unknown2', 'hall-unknown14']
#
# Class 77: ['barnabas', 'clement', 'justinmartyr', 'tertullian', 'hermas', 'massillon-jean']
#
# Class 78: ['thompson-unknown6', 'elizalde-manuel', 'ingersoll-charles2', 'mina-unknown', 'bradburn-unknown', 'graham-susan']
#
# Class 79: ['hammond-unknown2', 'porter-unknown', 'thorndike-charles', 'smith-louisa', 'harrod-anna', 'gay-unknown']
#
# Class 80: ['thorton-william', 'hayden-unknown', 'peter-america', 'reed-william', 'hatch-unknown', 'richardson-unknown2']
#
# Class 81: ['riddle-unknown', 'cooper-unknown4', 'king-unknown6', 'nowland-dado', 'marston-ward', 'tomms-unknown']
#
# Class 82: ['mcdowell-unknown', 'christian-unknown', 'frederick-vi', 'tucker-stgeorge', 'smyth-george', 'kempt-james']
#
# Class 83: ['johnson-james6', 'ray-james', 'lecor-carlos', 'tunstall-unknown', 'crittenden-john', 'noble-lazarus']
#
# Class 84: ['wade-unknown2', 'wade-unknown3', 'smith-unknown17', 'ogden-aaron', 'ouran-unknown', 'marbury-william']
#
# Class 85: ['nicholls-j', 'bryant-unknown', 'ebeling-christoph', 'ware-henry2', 'parker-isaac', 'hippocrates']
#
# Class 86: ['deming-unknown', 'warrington-unknown', 'ward-n', 'karthaus-unknown', 'armstrong-william', 'Willis Alston']
#
# Class 87: ['martens-georg', 'desa-joao', 'jenkins-robert', 'desa-pantaleon', 'cromwell-oliver', 'wedeljarlsberg-frederik']
#
# Class 88: ['whetcroft-sarah', 'stewart-unknown4', 'hackley-virginia', 'hackley-richard', 'lawrence-unknown', 'kerr-henrietta']
#
# Class 89: ['dewolf-unknown7', 'whitcomb-elizabeth', 'whitcomb-tilly', 'whitcomb-catherine', 'clough-unknown', 'ingalls-william']
#
# Class 90: ['allen-john2', 'hughes-n', 'allen-unknown8', 'clarke-robert', 'williams-nathan', 'higdan-gustavus']
#
# Class 91: ['mandeville-james', 'lane-unknown', 'williamson-isaac', 'gale-unknown', 'colver-daniel', 'stockton-unknown3']
#
# Class 92: ['hall-unknown16', 'lynch-dominick', 'baring-unknown', 'williamson-unknown3', 'smyth-william', 'fuller-h']
#
# Class 93: ['corby-unknown', 'borbridge-t', 'johnson-peter', 'robertson-george2', 'balmain-andrew', 'wilson-john4']
#
# Class 94: ['wistar-thomas', 'lee-henry2', 'skinner-unknown', 'hayne-isaac', 'battle-samuel', 'newbold-william']
#
# Class 95: ['davizac-august', 'livington-maria', 'harper-unknown', 'worthingon-william', 'watts-unknown', 'smith-john8']
#
# Class 96: ['corcoran-thomas', 'hughes-john', 'bakewell-l', 'ogilvie-james', 'blunt-j', 'young-unknown5']
#
# Class 97: ['ziba', 'thompson-charles', 'rodgers-george', 'mephibosheth', 'gardner-unknown6', 'henley-robert']
#
# Class 98: ['francis-i', 'elliott-william', 'fiske-unknown3', 'blagrove-william', 'elliott-unknown']
#
# Class 99: ['coffin-unknown', 'alston-william', 'girard-unknown2', 'girard-unknown', 'coffin-unknown2']
#
# Class 100: ['hawkins-benjamin', 'hawkins-unknown2', 'campbell-unknown', 'anderson-unknown10', 'hurtado-manuel']
#
# Class 101: ['carvadossy-ignazio', 'byrne-maria', 'huygens-constantia', 'huygens-unknown', 'cortildi-unknown']
#
# Class 102: ['hart-unknown', 'johnson-charles', 'cotheal-henry', 'hull-ann', 'cotheal-david']
#
# Class 103: ['lee-samuel', 'lee-francis', 'johnson-joseph', 'lee-richard2', 'keene-arthur']
#
# Class 104: ['grotius-hugo', 'barbeyrac-jean', 'burlamaqui-jean', 'lewis-eleanor2', 'lewis-eleanor']
#
# Class 105: ['howland-unknown2', 'bingham-unknown', 'curtis-unknown2', 'james-unknown', 'lytle-unknown']
#
# Class 106: ['austin', 'madan-unknown', 'dashiell-unknown', 'leo-xii', 'ambrose']
#
# Class 107: ['mayer-christian', 'muhammadali', 'giddings-salmon', 'morena-guerra', 'byers-unknown']
#
# Class 108: ['green-unknown2', 'blome-unknown', 'fagel-henry', 'irujo-carlos', 'nagell-unknown']
#
# Class 109: ['alden-r', 'dean-unknown2', 'houston-john', 'patterson-thomas', 'breckinridge-john']
#
# Class 110: ['brent-unknown2', 'charlesemmanuel', 'george-iii', 'pearson-unknown3', 'pearson-unknown2']
#
# Class 111: ['priestley-joseph', 'andrews-nathaniel', 'marks-unknown', 'heredia-unknown2', 'browne-unknown']
#
# Class 112: ['prentiss-unknown5', 'harley-robert', 'bolingbroke-henry', 'pryor-brazier', 'anne']
#
# Class 113: ['martin-unknown', 'randolph-unknown', 'leakin-sheppard', 'armstrong-unknown', 'girardin-louis']
#
# Class 114: ['dupont-e', 'reeder-benjamin', 'hawkins-james', 'alvey-unknown2', 'beeson-jacob']
#
# Class 115: ['hickey-unknown', 'ridgley-unknown2', 'forrest-unknown2', 'forrest-george', 'hanson-i']
#
# Class 116: ['rogers-john', 'hardin-unknown', 'ives-unknown4', 'caldwell-elias ', 'larned-unknown2']
#
# Class 117: ['roberts-e', 'leland-unknown', 'randolph-william', 'ross-henry', 'denison-unknown2']
#
# Class 118: ['patterson-unknown4', 'griffith-unknown4', 'coyle-unknown', 'griffith-unknown3', 'salter-unknown']
#
# Class 119: ['santaanna-antonio', 'martigny-buchet', 'littleprince', 'lawless-unknown', 'harrow-unknown']
#
# Class 120: ['gales-sarah', 'child-unknown2', 'selkirk-thomas', 'hoffman-unknown', 'foster-w']
#
# Class 121: ['sergeant-thomas', 'robertson-unknown', 'patterson-robert', 'nicholls-unknown', 'corbin-unknown']
#
# Class 122: ['chauncey-charles', 'sergeant-unknown', 'hall-unknown6', 'miller-unknown5', 'keyworth-unknown']
#
# Class 123: ['sever-unknown', 'fiske-moses', 'apthorp-unknown2', 'lincoln-levi', 'apthorp-mary']
#
# Class 124: ['sharp-daniel', 'brown-unknown8', 'drane-unknown', 'dalliba-unknown', 'bowles-unknown']
#
# Class 125: ['chastant-l', 'shewell-l', 'ralston-robert2', 'girard-stephen', 'elbers-b']
#
# Class 126: ['gallaudet-thomas', 'simpson-stephen', 'clark-unknown3', 'elkins-jeremiah', 'crary-unknown']
#
# Class 127: ['brashears-unknown', 'spencer-jesse', 'butler-samuel', 'coxe-j', 'gardner-benjamin']
#
# Class 128: ['rodde-diedrich', 'bates-unknown', 'bard-unknown', 'sweney-unknown', 'mcknight-unknown2']
#
# Class 129: ['carter-charles', 'stoddert-benjamin', 'taylor-unknown9', 'coolidge-william', 'taylor-robert2']
#
# Class 130: ['sturgis-russell', 'eustaphieve-sarah', 'bowditch-nathaniel', 'thorndike-n', 'eustaphieve-unknown']
#
# Class 131: ['havens-philetus', 'timmons-unknown2', 'tanner-archibald', 'coote-c', 'fuller-unknown4']
#
# Class 132: ['rutherford-unknown', 'sanderson-james', 'greene-james', 'veitch-richard', 'bill-a']
#
# Class 133: ['brown-a', 'walker-unknown', 'upham-unknown2', 'swift-william', 'harris-unknown2']
#
# Class 134: ['moliere', 'davidson-william', 'wallack-henry', 'hale-thomas', 'cassio']
#
# Class 135: ['maxwell-james', 'bayard-unknown', 'percival-james', 'plitt-john', 'walsh-unknown']
#
# Class 136: ['hilliard-william', 'mackay-unknown', 'sullivan-william', 'walter-lynde', 'taggard-william']
#
# Class 137: ['dearborn-alexander', 'newman-unknown3', 'waters-unknown2', 'morton-unknown2', 'goodwin-unknown']
#
# Class 138: ['bond-unknown3', 'west-unknown2', 'wainwright-unknown', 'palmer-unknown', 'symms-uknown']
#
# Class 139: ['hillhouse-james2', 'polk-james', 'moore-thomas', 'white-charles', 'griffith-unknown']
#
# Class 140: ['whitman-unknown', 'brown-unknown10', 'gill-moses', 'robinson-unknown', 'greenwood-unknown3']
#
# Class 141: ['rog-john', 'frederick-francis', 'peterson-nils', 'milligan-unknown', 'williams-john2']
#
# Class 142: ['fullerton-david', 'kent-unknown', 'andrews-unknown3', 'williams-unknown3', 'robinson-moncure']
#
# Class 143: ['finley-unknown', 'tucker-unknown3', 'coleman-chapman', 'robins-unknown2', 'winslow-isaac']
#
# Class 144: ['rowley-charles', 'woodbine-george', 'baker-unknown2', 'arbuthnot-alexander', 'emmons-richard']
#
# Class 145: ['middleton-mary', 'liston-robert', 'woodbridge-unknown', 'halkett-katherine', 'bond-unknown']
#
# Class 146: ['grumio', 'woodville-unknown', 'cumberland-richard', 'sirdaviddaw', 'penruddock']
#
# Class 147: ['lippincott-william', 'mosley-unknown', 'wurts-john', 'anderson-unknown11', 'lippincott-joshua']
#
# Class 148: ['cottringer-harriet', 'cottringer-cornelia', 'cottringer-bridget', 'cottringer-anne']
#
# Class 149: ['brown-unknown18', 'barnard-samuel', 'cushman-hercules', 'bogan-unknown']
#
# Class 150: ['gardner-unknown5', 'brook-unknown2', 'delord-unknown', 'brook-unknown']
#
# Class 151: ['cutting-nathaniel', 'haines-unknown', 'burnett-unknown2', 'burnett-unknown']
#
# Class 152: ['dewolf-nancy', 'cazenove-unknown', 'hall-unknown19', 'dodge-unknown']
#
# Class 153: ['hodgkinson-john', 'bussche-calmor', 'caulaincourt-armand', 'dunlop-william']
#
# Class 154: ['clarke-george3', 'hubbart-unknown', 'church-john2', 'cross-unknown']
#
# Class 155: ['cooper-unknown6', 'canby-unknown', 'bunce-isaiah', 'jenks-unknown']
#
# Class 156: ['knox-unknown', 'blount-unknown', 'fuller-unknown3', 'codman-stephen']
#
# Class 157: ['leggett-william', 'adams-unknown6', 'adams-margaret', 'gaer-unknown']
#
# Class 158: ['marrast-unknown', 'edgar', 'kinglear', 'cordelia']
#
# Class 159: ['greenleaf-anna', 'davis-ellen', 'baker-unknown3', 'marston-unknown5']
#
# Class 160: ['masi-unknown', 'baker-unknown8', 'barnes-isaac', 'barnes-vachel']
#
# Class 161: ['conner-henry', 'mcilvaine-james', 'collins-ela', 'eaton-lewis']
#
# Class 162: ['fowler-unknown', 'monroe-emily', 'backus-unknown', 'moulton-john']
#
# Class 163: ['neal-daniel', 'crittenden-robert', 'mccloskey-unknown', 'alexander-vi']
#
# Class 164: ['costen-unknown', 'davie-william', 'murray-william2', 'nelson-unknown2']
#
# Class 165: ['irvine-callender', 'constantine3', 'burch-samuel', 'niles-unknown']
#
# Class 166: ['dewey-unknown', 'noble-unknown', 'greer-unknown', 'ellery-unknown']
#
# Class 167: ['berkeley-unknown2', 'noland-unknown2', 'berkeley-unknown', 'armistead-unknown']
#
# Class 168: ['anderson-patience', 'cooper-unknown2', 'nourse-henry', 'cooper-unknown3']
#
# Class 169: ['furman-unknown', 'manzo-diego', 'lee-catherine', 'oakley-unknown']
#
# Class 170: ['lee-archer', 'phillips-elizabeth', 'cooke-j', 'forrest-b']
#
# Class 171: ['edwards-james', 'jair', 'jephthah', 'phillips-wever']
#
# Class 172: ['charlotte2', 'brown-unknown14', 'pollard-unknown', 'heredia-narciso']
#
# Class 173: ['griswold-unknown', 'hutchinson-titus', 'paine-elijah', 'prince-james']
#
# Class 174: ['putnam-unknown2', 'putnam-unknown', 'putnam-samuel', 'pickman-unknown2']
#
# Class 175: ['randall-unknown5', 'hagner-frances', 'gudgeon-james', 'pickering-enos']
#
# Class 176: ['rapelje-georg', 'rapelje-susanna', 'dorsey-clement', 'provoost-samuel']
#
# Class 177: ['cabell-william', 'rich-o', 'appleton-john2', 'cabell-agnes']
#
# Class 178: ['duncan', 'ladymacbeth', 'macbeth', 'richardthe3rd']
#
# Class 179: ['clifton-unknown', 'griscom-john', 'rivers-thomas', 'edes-henry']
#
# Class 180: ['polk-ann', 'rivoes-unknown', 'granger-unknown', 'gray-unknown4']
#
# Class 181: ['bradford-william', 'brooke-samuel', 'marmontel-jean', 'roane-samuel']
#
# Class 182: ['mickle-william', 'robertson-unknown4', 'brito-unknown', 'camoen-luis']
#
# Class 183: ['robertson-unknown5', 'dick-unknown', 'peter-george', 'goodsell-unknown']
#
# Class 184: ['custis-elizabeth', 'peter-david', 'peter-sarah', 'rogers-eliza']
#
# Class 185: ['johnson-thomas', 'rogers-unknown', 'johnson-elizabeth', 'hone-unknown']
#
# Class 186: ['larned-unknown3', 'root-c', 'baum-unknown', 'morell-john']
#
# Class 187: ['burr-jonathan', 'dearborn-benjamin', 'pollock-allan', 'rose-robert']
#
# Class 188: ['ross-james2', 'forsth-john', 'niles-william', 'massey-unknown3']
#
# Class 189: ['ridge-major', 'lowry-george', 'ross-john', 'hicks-charles']
#
# Class 190: ['lasage-unknown', 'russell-unknown5', 'russell-unknown4', 'lewis-joel']
#
# Class 191: ['murat-unknown', 'samuel', 'green-thomas2', 'agag']
#
# Class 192: ['sanford-unknown3', 'cutbush-unknown', 'sanford-unknown2', 'alvy-unknown']
#
# Class 193: ['pope-alexander', 'ironside-unknown2', 'sappho', 'hadrian']
#
# Class 194: ['amory-catherine', 'pickman-hannah', 'foster-elizabeth', 'sargent-hannah']
#
# Class 195: ['fox-thomas', 'shain-b', 'blake-thomas', 'fox-w']
#
# Class 196: ['newell-theodore', 'shapleigh-reuben', 'carter-unknown4', 'croes-john']
#
# Class 197: ['coleman-mary', 'sibley-unknown', 'maynard-unknown', 'colman-unknown2']
#
# Class 198: ['simmons-unknown5', 'middleton-ann', 'bradley-patrick', 'crufts-edward']
#
# Class 199: ['mrsmalaprop', 'siranthonyabsolute', 'calebquotem', 'etzler-unknown']
#
# Class 200: ['clack-john', 'skinner-unknown2', 'otis-unknown', 'clack-louisa']
#
# Class 201: ['johnson-james5', 'euclid', 'colby-unknown', 'smith-hall']
#
# Class 202: ['eldridge-unknown', 'hill-isaac', 'dennis-unknown2', 'southad-samuel']
#
# Class 203: ['humphreys-h', 'southard-john', 'riveria-unknown', 'gardner-unknown4']
#
# Class 204: ['baldwin-b', 'adams-unknown5', 'stevens-unknown3', 'clark-unknown5']
#
# Class 205: ['march-unknown', 'lythe-unknown', 'pell-f', 'stuart-andrew']
#
# Class 206: ['jenkinson-charles', 'styles-unknown', 'polk-william', 'brent-henry']
#
# Class 207: ['suter-unknown', 'berald-unknown', 'cumming-ann', 'labranche-unknown2']
#
# Class 208: ['silsby-enoch', 'roberdeau-issac', 'tatom-unknown', 'henshaw-unknown']
#
# Class 209: ['timberlake-unknown3', 'timberlake-unknown2', 'dugan-unknown', 'timberlake-unknown']
#
# Class 210: ['azuni-domenico', 'fulton-robert', 'bond-unknown2', 'towson-unknown2']
#
# Class 211: ['tufts-quincy', 'tufts-mercy', 'tufts-cotton', 'tufts-susannah']
#
# Class 212: ['patterson-unknown6', 'dunglison-robley', 'twichel-unknown', 'long-george']
#
# Class 213: ['lincoln-heman', 'unknown15', 'parker-unknown', 'robertson-unknown2']
#
# Class 214: ['kinnard-unknown', 'henry-r3', 'reed-unknown5', 'unknown16']
#
# Class 215: ['smith-benjamin', 'devalnais-calista', 'upham-unknown', 'hunnewell-walter']
#
# Class 216: ['blood-unknown', 'axel-unknown', 'vail-unknown3', 'smith-william5']
#
# Class 217: ['franks-unknown', 'vanderkemp-frances', 'kirkland-unknown', 'mckenney-unknown']
#
# Class 218: ['earl-elias', 'vanhook-unknown', 'foster-william', 'dekalb-johann']
#
# Class 219: ['stratford-canning', 'barry-unknown', 'vansittart-nicholas', 'roy-unknown2']
#
# Class 220: ['sibley-unknown2', 'hall-unknown17', 'vinson-unknown', 'strong-unknown2']
#
# Class 221: ['crawson-unknown', 'dunn-john', 'wadsworth-unknown2', 'terry-unknown']
#
# Class 222: ['vanrensselaer-cornelia', 'wales-george', 'breck-hannah', 'vanrensselaer-unknown3']
#
# Class 223: ['massey-unknown2', 'dwight-unknown', 'verplanck-s', 'walsh-unknown2']
#
# Class 224: ['hooe-unknown', 'hercules', 'ware-betsey', 'bernstorff-christian']
#
# Class 225: ['savage-james', 'warren-john', 'phillips-unknown5', 'belzoni-giovanni']
#
# Class 226: ['warren-joseph', 'law-frances', 'carter-landon', 'stevenson-unknown3']
#
# Class 227: ['aury-louis', 'jebb-john', 'waterhouse-unknown', 'maffitt-john']
#
# Class 228: ['walker-unknown3', 'webb-samuel', 'webb-henry', 'huntington-unknown']
#
# Class 229: ['sage-e', 'wells-samuel', 'waugh-charles', 'livingston-r']
#
# Class 230: ['west-benjamin', 'scott-unknown5', 'wells-unknown2', 'nickson-unknown']
#
# Class 231: ['coke-edward', 'weymouth-unknown2', 'eaton-unknown3', 'stackleberg-berndt']
#
# Class 232: ['wheelwright-unknown', 'kearney-francis', 'lazwell-unknown', 'mcclure-unknown']
#
# Class 233: ['whetcroft-juliana', 'curtoys-unknown', 'marshall-humphrey', 'marshall-thomas']
#
# Class 234: ['mclean-rebecca', 'creighton-unknown', 'gough-unknown', 'whitcomb-unknown4']
#
# Class 235: ['white-norman', 'sampson-unknown2', 'canedy-peleg', 'read-unknown2']
#
# Class 236: ['grivel-jean', 'duncan-e', 'whitlock-ephraim', 'burke-unknown']
#
# Class 237: ['wichelhausen-frederick', 'cushing-thomas', 'livingston-newman', 'burbeck-unknown']
#
# Class 238: ['drake-john', 'willett-marinus', 'low-unknown', 'ireland-w']
#
# Class 239: ['william-john', 'prudy-robert', 'overton-john', 'burdick-unknown']
#
# Class 240: ['williams-nathaniel2', 'hathaway-silas', 'whittington-unknown', 'little-unknown5']
#
# Class 241: ['queen-nicolas', 'rodney-unknown', 'wilson-john', 'rodney-susan']
#
# Class 242: ['tayloe-edward-thornton', 'wilson-unknown5', 'tinges-john', 'piere-unknown']
#
# Class 243: ['winthrop-elizabeth', 'austin-catherine', 'everett-john', 'blake-sarah']
#
# Class 244: ['gray-unknown6', 'withy-george', 'payton-ann', 'ball-miriam']
#
# Class 245: ['childs-unknown2', 'wood-unknown3', 'thomas-unknown3', 'curtis-unknown']
#
# Class 246: ['wyllys-john', 'shee-parke', 'lee-charles', 'mccorkle-william']
#
# Class 247: ['comyn-unknown', 'boardman-unknown3', 'comyn-unknown2']
#
# Class 248: ['debbate-gaspare', 'bibby-unknown3', 'bibby-unknown2']
#
# Class 249: ['astor-john', 'elkins-unknown', 'coxe-isaac']
#
# Class 250: ['elkins-unknown2', 'brody-unkown', 'dickins-unknown2']
#
# Class 251: ['clough-ebenezer', 'davis-unknown9', 'fenwick-benedict']
#
# Class 252: ['gettys-james', 'cassedy-unknown', 'cassedy-unknown2']
#
# Class 253: ['gill-moses2', 'boylston-zabdiel', 'boylston-sally']
#
# Class 254: ['cutts-unknown', 'eustis-jacob', 'gray-unknown5']
#
# Class 255: ['gardner-rebecca', 'gray-elizabeth2', 'greenleaf-mary']
#
# Class 256: ['gregory-unknown3', 'cunningham-henry', 'bulley-michael']
#
# Class 257: ['grouchy-unknown', 'gray-w', 'artiguenave-joseph']
#
# Class 258: ['burrows-unknown2', 'agnew-unknown', 'halsey-unknown']
#
# Class 259: ['hand-unknown2', 'hand-joseph', 'hand-unknown3']
#
# Class 260: ['hull-andrew', 'call-unknown', 'christophe-henri']
#
# Class 261: ['hutchinson-thomas', 'austin-benjamin', 'brackett-thomas']
#
# Class 262: ['hall-unknown10', 'ingersoll-mary', 'hall-unknown11']
#
# Class 263: ['ingraham-joseph', 'ingraham-unknown', 'ingraham-sarah']
#
# Class 264: ['cambrelang-churchill', 'dawson-unknown', 'irving-unknown']
#
# Class 265: ['haynes-unknown', 'jackson-unknown3', 'elkison-unknown']
#
# Class 266: ['betzolt-unknown', 'french-unknown3', 'johnstone-unknown']
#
# Class 267: ['gallatin-joseph', 'kater-henry', 'cooper-james']
#
# Class 268: ['keating-john', 'hall-unknown18', 'davis-unknown7']
#
# Class 269: ['kendall-unknown', 'hodges-samuel', 'jenny-unknown']
#
# Class 270: ['barnet-issac', 'laine-joseph', 'beasley-reuben']
#
# Class 271: ['leamy-john', 'jackson-james', 'johnson-james4']
#
# Class 272: ['lecain-sarah', 'dawes-margaret', 'cruft-edward2']
#
# Class 273: ['long-g', 'crawford-joseph', 'lovegrove-unknown']
#
# Class 274: ['fay-john', 'horsey-outerbridge', 'maclay-william']
#
# Class 275: ['malcomson-unknown', 'davis-unknown', 'harvey-unknown']
#
# Class 276: ['maturin-charles', 'mahy-unknown', 'fordham-unknown']
#
# Class 277: ['coyle-f', 'doiley', 'mcintosh-unknown']
#
# Class 278: ['melcher-joseph', 'brown-unknown11', 'mcrae-unknown2']
#
# Class 279: ['mellen-prentiss', 'levy-nathan', 'abbot-unknown']
#
# Class 280: ['melville-unknown', 'barton-joshua', 'mackey-unknown']
#
# Class 281: ['bayard-john', 'milligan-unknown2', 'carroll-henry']
#
# Class 282: ['manigault-unknown', 'mitchell-edward', 'lloyd-unknown3']
#
# Class 283: ['monroe-hulda', 'davis-matthew', 'bird-charles']
#
# Class 284: ['mcpherson-unknown2', 'mcpherson-john', 'montgomery-richard']
#
# Class 285: ['brian-unknown', 'foote-ebenezer', 'moore-jacob']
#
# Class 286: ['moran-unknown', 'loyall-unknown', 'archer-robert']
#
# Class 287: ['colnet-james', 'martinez-esteban', 'morton-unknown4']
#
# Class 288: ['moulder-john', 'moulder-unknown', 'hill-unknown2']
#
# Class 289: ['mumford-gurdon', 'dewindt-unknown', 'duer-john']
#
# Class 290: ['muzquiz-melchor', 'dumas-unknown', 'angus-ann']
#
# Class 291: ['bird-unknown2', 'carter-t', 'myers-d']
#
# Class 292: ['carter-william', 'nelson-unknown4', 'cousins-unknown']
#
# Class 293: ['nevins-william', 'blanford-unknown', 'deherty-unknown']
#
# Class 294: ['lane-joshua', 'gibbons-james', 'nicholas-p']
#
# Class 295: ['louis-xv', 'dixon-henry', 'ohiggins-bernardo']
#
# Class 296: ['davis-john4', 'lincoln-john', 'payne-unknown3']
#
# Class 297: ['english-thomas', 'bradley-william', 'perkins-unknown2']
#
# Class 298: ['perry-elizabeth', 'brown-paul', 'herder-johann']
#
# Class 299: ['petabonaqua', 'mcguire-unknown3', 'nowokeshik']
#
# Class 300: ['kersey-jesse', 'peters-unknown3', 'jones-george']
#
# Class 301: ['moore-andrew', 'philidor-francois', 'ketch-jack']
#
# Class 302: ['niel-francis', 'pope-hardy', 'handy-edward']
#
# Class 303: ['mason-powell', 'prescott-edward', 'prescott-william2']
#
# Class 304: ['fleitas-unknown', 'anderson-thomas', 'prudhomme-unknown']
#
# Class 305: ['campbell-edward', 'campbell-maria', 'randolph-edmund']
#
# Class 306: ['randolph-david', 'randolph-unknown5', 'gurnell-unknown']
#
# Class 307: ['elliott-unknown3', 'randolph-unknown3', 'rapine-unknown2']
#
# Class 308: ['ratcliff-unknown2', 'nathanael', 'ratcliff-unknown']
#
# Class 309: ['redd-unknown', 'dillett-unknown', 'bullock-uknown']
#
# Class 310: ['fisher-issac', 'cabot-unknown', 'reddick-unknown']
#
# Class 311: ['livermore-edward', 'popkin-john', 'reed-reuben']
#
# Class 312: ['retzsch-moritz', 'byrd-charles', 'goethe-johann']
#
# Class 313: ['ridgley-unknown', 'griffin-unknown2', 'lefebvredesnouettes-charles']
#
# Class 314: ['clement-unknown', 'cobb-unknown', 'riley-unknown']
#
# Class 315: ['rittenhouse-benjamin', 'brown-unknown17', 'mckenney-benson']
#
# Class 316: ['robinson-w', 'read-unknown', 'gregory-george']
#
# Class 317: ['rodgers-lloyd', 'lord-unknown', 'fisher-unknown2']
#
# Class 318: ['dukearanzo', 'petruchio', 'rolande']
#
# Class 319: ['garnett-charlotte', 'ronckendorf-mary', 'lewis-unknown10']
#
# Class 320: ['miller-unknown2', 'mullet-unknown', 'root-erastus']
#
# Class 321: ['burr-unknown2', 'russell-unknown7', 'gage-unknown']
#
# Class 322: ['rutgers-unknown', 'rutgers-unknown2', 'lloyd-unknown']
#
# Class 323: ['hill-ishmael', 'sage-nathan', 'easton-joseph']
#
# Class 324: ['mayo-julia', 'scott-maria', 'mayo-abigail']
#
# Class 325: ['munroe-unknown', 'morse-james', 'scott-unknown2']
#
# Class 326: ['killeran-edward', 'peyton-unknown', 'seabury-unknown']
#
# Class 327: ['ritchie-george', 'shaw-thomas', 'pope-n']
#
# Class 328: ['franks-unknown2', 'rogers-t', 'shoemaker-unknown']
#
# Class 329: ['sirpeterteazle', 'ladyteazle', 'charlessurface']
#
# Class 330: ['crabb-thomas', 'fillebrown-thomas', 'skinner-charles']
#
# Class 331: ['slade-unknown', 'patterson-john', 'rich-unknown']
#
# Class 332: ['burnett-charles', 'slacum-noland', 'smith-richard2']
#
# Class 333: ['mason-unknown7', 'griffiths-unknown', 'smith-william6']
#
# Class 334: ['snowden-thomas', 'harrison-unknown5', 'miles-unknown']
#
# Class 335: ['stelle-pontius', 'stelle-unknown', 'flat-unknown']
#
# Class 336: ['hall-unknown12', 'charles-ii', 'sterling-unknown2']
#
# Class 337: ['sterrett-james', 'anderson-unknown9', 'hare-lewis']
#
# Class 338: ['huskisson-william', 'stewart-arabella', 'snowden-gerard']
#
# Class 339: ['buck-henry', 'stockton-robert', 'koetsier-unknown']
#
# Class 340: ['allen-ira', 'stoddard-amos', 'hunt-unknown4']
#
# Class 341: ['storer-bellamy', 'arnold-unknown2', 'newbold-unknown']
#
# Class 342: ['stoughton-unknown2', 'stoughton-john', 'colt-unknown']
#
# Class 343: ['stuart-charles2', 'pinckney-william2', 'coxe-unknown2']
#
# Class 344: ['doyle-percy', 'sturt-henry', 'key-francis2']
#
# Class 345: ['dallas-arabella', 'lathrop-john', 'sullivan-george2']
#
# Class 346: ['sullivan-richard', 'sullivan-unknown4', 'humphreys-unknown2']
#
# Class 347: ['hancock-john3', 'sutton-unknown', 'hancock-ebenezer']
#
# Class 348: ['tastet-unknown', 'cunningham-john', 'damon']
#
# Class 349: ['hay-unknown', 'pasha-mehmed', 'tayloe-henrietta']
#
# Class 350: ['macey-unknown', 'tayloe-james', 'ring-rufus']
#
# Class 351: ['montmorency-mathieu', 'harrington-unknown', 'thacher-unknown']
#
# Class 352: ['marston-jane', 'marston-emily', 'thayer-unknown2']
#
# Class 353: ['thomas', 'erving-john', 'perkins-george']
#
# Class 354: ['teneyck-egbert', 'thomas-g', 'long-unknown4']
#
# Class 355: ['durant-cornelius', 'ritchie-maria', 'thomas-rebecca']
#
# Class 356: ['milligan-unknown3', 'thompson-hugh', 'stewart-james']
#
# Class 357: ['robbins-unknown', 'todd-william', 'beebe-unknown']
#
# Class 358: ['tooker-unknown', 'richardson-unknown', 'prentiss-unknown2']
#
# Class 359: ['sprague-unknown3', 'pearce-unknown3', 'townsend-alexander']
#
# Class 360: ['ogden-david', 'dunbar-unknown', 'townsend-unknown']
#
# Class 361: ['scion-unknown', 'lotswife', 'towson-unknown3']
#
# Class 362: ['travers-unknown2', 'hutchinson-israel', 'hamilton-unknown6']
#
# Class 363: ['trezvant-james', 'davis-unknown8', 'seawell-francis']
#
# Class 364: ['smith-unknown7', 'patterson-unknown5', 'trimble-unknown']
#
# Class 365: ['matthews-unknown', 'katchell-unknown', 'turner-unknown4']
#
# Class 366: ['vanderbilt-cornelius', 'brodie-alexander', 'mccormick-unknown']
#
# Class 367: ['snowden-unknown', 'vanderzea-unknown', 'lehmanowsky-john']
#
# Class 368: ['vanhorn-espy', 'stansbury-tobias', 'cummins-unknown2']
#
# Class 369: ['vanranst-cornelius', 'davis-unknown4', 'harrison-james']
#
# Class 370: ['varela-felix', 'suarez-leonardo', 'gener-tomas']
#
# Class 371: ['stull-j', 'vernon-t', 'timmons-unknown']
#
# Class 372: ['vernon-unknown', 'vernon-william', 'lafeyette']
#
# Class 373: ['meyer-unknown2', 'lowrie-water', 'verplank-william']
#
# Class 374: ['wagg-unknown', 'lyford-william', 'wagg-unknown2']
#
# Class 375: ['blair-samuel', 'ross-unknown5', 'walker-elizabeth2']
#
# Class 376: ['child-unknown3', 'walker-james', 'child-unknown4']
#
# Class 377: ['henderson-francis2', 'polignac-jules', 'waln-jacob']
#
# Class 378: ['clarke-john', 'walter-unknown', 'hale-unknown2']
#
# Class 379: ['apthorp-unknown3', 'walton-william', 'lucas-unknown']
#
# Class 380: ['cramer-john', 'waring-unknown2', 'thayer-unknown3']
#
# Class 381: ['prime-nathaniel', 'neale-unknown', 'watkins-mary']
#
# Class 382: ['allen-unknown6', 'watson-unknown3', 'allen-unknown5']
#
# Class 383: ['shall-unknown', 'watson-unknown4', 'adams-louisa-catherine']
#
# Class 384: ['colesbury-william', 'plantou-julia', 'webster-noah']
#
# Class 385: ['weld-unknown', 'weld-b', 'fry-s']
#
# Class 386: ['welles-unknown2', 'drummond-unknown', 'garry-unknown']
#
# Class 387: ['welsh-unknown2', 'elwyn-unknown2', 'welsh-thomas2']
#
# Class 388: ['hunt-unknown3', 'wendover-peter', 'davidson-william2']
#
# Class 389: ['wever-unknown2', 'hamilton-archibald', 'gallaher-jonathan']
#
# Class 390: ['jeremydidler', 'smith-thomas2', 'wheatley-frederick']
#
# Class 391: ['whittlesea-unknown', 'dougherty-unknown', 'miner-unknown2']
#
# Class 392: ['green-unknown4', 'whittlesey-unknown', 'custis-mary']
#
# Class 393: ['clark-simon', 'wilhelmina', 'detubeuf-unknown']
#
# Class 394: ['williams-cumberland', 'bezeah-william', 'hogdson-unknown2']
#
# Class 395: ['williams-nicholas', 'williams-louis', 'willcocks-joseph']
#
# Class 396: ['williams-samuel', 'wheat-unknown', 'abraham']
#
# Class 397: ['williams-seth', 'bailey-unknown4', 'nahash']
#
# Class 398: ['williams-unknown', 'kirby-reynolds', 'gardner-w']
#
# Class 399: ['forsyth-samuel', 'stevenson-unknown2', 'willing-thomas']
#
# Class 400: ['willink-wilhem2', 'willink-wilhem', 'willink-jan']
#
# Class 401: ['smith-unknown12', 'wilson-elizabeth', 'miller-morris']
#
# Class 402: ['wilson-w', 'loney-john', 'loney-william']
#
# Class 403: ['gunnell-unknown', 'gow-unknown', 'wood-unknown2']
#
# Class 404: ['lewis-unknown3', 'wood-w', 'glase-j']
#
# Class 405: ['mitchel-james', 'myer-salome', 'worman-ludwig']
#
# Class 406: ['pearson-joseph', 'pattison-granville', 'worthington-catherine']
#
# Class 407: ['brown-unknown15', 'yates-unknown', 'preble-h']
#
# Class 408: ['young-david', 'sylvanus', 'selkirk-dunbar']
#
# Class 409: ['judas-iscariot', 'young-unknown', 'elijah']
#
# Class 410: ['young-unknown4', 'jabez', 'woodhull-selah']
#
# CPU times: user 56.2 ms, sys: 23.6 ms, total: 79.8 ms
# Wall time: 115 ms

# %% [markdown]
# ## Export graph object into Gephi's GEXF format.

# %%
# %%time

nx.write_gexf(G, 'jqa_papers.gexf')
# Out:
# CPU times: user 260 ms, sys: 8.21 ms, total: 268 ms
# Wall time: 269 ms
