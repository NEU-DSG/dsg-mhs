# %% [markdown]
# # Topic Model -- Sedgwick

# %%
# Import necessary libraries.
import re, nltk, warnings, csv, sys, os, pickle, glob
import pandas as pd
import numpy as np
import seaborn as sns
from itertools import chain
from scipy import stats

# Import NLTK packages.
from nltk import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords

# Import sklearn packages.
from sklearn.decomposition import LatentDirichletAllocation as LDA
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# Import LDA visualizer.
import pyLDAvis, pyLDAvis.sklearn
pyLDAvis.enable_notebook()

# Import and append stopwords.
stop_words = stopwords.words("english")
stop_words.append(['mr', 'dear'])

# Ignore warnings related to deprecated functions.
warnings.simplefilter("ignore", DeprecationWarning)

# Import project-specific functions. 
# Python files (.py) have to be in same folder to work.
lib_path = os.path.abspath(os.path.join(os.path.dirname('Correspondence_XML_parser.py'), '../Scripts'))
sys.path.append(lib_path)

from Correspondence_XML_parser import *

# Read in config.py (git ignored file) for API username and pw.
config_path = os.path.abspath(os.path.join(os.path.dirname('config.py'), '../Scripts'))
sys.path.append(config_path)
import config

# url = 'https://dsg.xmldb-dev.northeastern.edu/basex/psc/' :: old
url = 'https://dsg.xmldb-dev.northeastern.edu/BaseX964/rest/psc/'
user = config.username
pw = config.password

# Get the correct file path to navigate to the github repository.
abs_dir = os.getcwd() + '/../../'

# %% [markdown]
# ## Gather XML Files

# %%
# %%time

# Remove this cell when files are in BaseX.
# Declare directory location to shorten filepaths later.
files = glob.glob(abs_dir + "../../Data/PSC/Sedgwick/*.xml")

len(files)
# Out:
# CPU times: user 973 µs, sys: 1.32 ms, total: 2.29 ms
# Wall time: 1.19 ms
# 122

# %%
# %%time

# # Must be connected to Northeastern's VPN.
# r = requests.get(url, 
#                  auth = (user, pw), 
#                  headers = {'Content-Type': 'application/xml'}
#                 )

# # Check status of URL
# print (r.status_code)

# # Read in contents of pipeline.
# soup = BeautifulSoup(r.content, 'html.parser')

# # Split soup's content by \n (each line is a file path to an XML doc).
# # Use filter() to remove empty strings ('').
# # Convert back to list using list().
# files = list(filter(None, soup.text.split('\n')))

# # # Filter list and retrieve only jqa/ files.
# # files = [i for i in files if 'jqa/' in i]

# # len(files)
# files

# %% [markdown]
# ## Build DataFrame

# %%
# %%time

# Build dataframe from XML files.
# build_dataframe() called from Correspondence_XML_parser
df = build_dataframe(files)

df.head(3)
# Out:
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1807-04-26-toFrancesSedgwickWatsonFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1803-10-06-toPamelaDwightSedgwickF.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1809-01-27-toTheodoreSedgwickIFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1807-12-25-toFrancesSedgwickWatsonFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1806-01-17-toPamelaDwightSedgwickFD (1).xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1805-11-29-toPamelaDwightSedgwickFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1807-04-26-toFSWF.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1800-01-12-toTheodoreSedgwickIF.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1805-11-15-toPamelaDwightSedgwickFD (1).xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1807-12-28-toFrancesSedgwickWatsonFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1807-03-24-toFrancesSedgwickWatsonFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1808-11-22-toTheodoreSedgwickIFD.xml
#
# /Users/quinn.wi/Documents/GitHub/dsg-mhs/Jupyter_Notebooks/TopicModels/../../../../Data/PSC/Sedgwick/CMS1806-01-17-toPamelaDwightSedgwickFD.xml
#
# CPU times: user 81.4 ms, sys: 14 ms, total: 95.4 ms
# Wall time: 117 ms
#                                          file        date  \
# 0    CMS1819-03-08-toRobertSedgwickIF (1).xml  1819-03-08
# 1  CMS1816-03-25-toFrancesSedgwickWatsonF.xml  1816-03-25
# 2        CMS1813-08-15-toRobertSedgwickIF.xml  1813-08-15
#
#                      source           target subjects  \
# 0  Catharine Maria Sedgwick  sedgwick-robert
# 1  Catharine Maria Sedgwick              FSW
# 2  Catharine Maria Sedgwick              RSI
#
#                                           references  \
# 0  sedgwick-charles,sedgwick-elizabeth,sedgwick-h...
# 1  RSI,banyer-maria,jay-sarah,van vechten-jacob,s...
# 2  FSW,U,payne-eloise,warner-thomas,warner-france...
#
#                                                 text
# 0  Albany March 8' 1819 -- I came here my dear Ro...
# 1  Albany March 25th 1816 I have just heard of an...
# 2   Stockbridge August 15th 1813 I recollect very...

# %% [markdown]
# ## Clean Data & Prepare for Topic Modeling

# %%
# %%time

# Drop duplicate texts (created from unnested subject headings) & count words.
doc_len = df['text'].str.split(' ').str.len() \
    .reset_index() \
    .drop_duplicates()

# Round word count.
doc_len = np.around(doc_len['text'], decimals = -1)

doc_len = pd.DataFrame(doc_len)

# Plot graph.
sns.set(rc = {"figure.figsize": (12, 6)})
sns.set_style("dark")
ax = sns.histplot(doc_len['text'])
# Out:
# CPU times: user 97.1 ms, sys: 5.64 ms, total: 103 ms
# Wall time: 103 ms

# %% [markdown]
# ### Chunk texts into equal lengths.

# %%
# %%time

chunk_size = 200

def splitText(string):
    words = string.split(' ')
    removed_stopwords = [w for w in words if w not in stop_words]
    grouped_words = [removed_stopwords[i: i + chunk_size] for i in range(0, len(removed_stopwords), chunk_size)]
    return grouped_words

df['text'] = df['text'].apply(splitText)

df = df.explode('text')

# Add word count field.
df['wordCount'] = df['text'].apply(lambda x: len(x))

# Join list of words into single string.
df['text'] = df['text'].apply(' '.join)

# Remove rows without text.
df = df.dropna(subset = ['text'])

# Remove texts with too few words (chunk_size - 50).
df = df.query('wordCount >= (@chunk_size - 50)')

df.head(3)
# Out:
# CPU times: user 132 ms, sys: 2.85 ms, total: 135 ms
# Wall time: 135 ms
#                                        file        date  \
# 0  CMS1819-03-08-toRobertSedgwickIF (1).xml  1819-03-08
# 0  CMS1819-03-08-toRobertSedgwickIF (1).xml  1819-03-08
# 0  CMS1819-03-08-toRobertSedgwickIF (1).xml  1819-03-08
#
#                      source           target subjects  \
# 0  Catharine Maria Sedgwick  sedgwick-robert
# 0  Catharine Maria Sedgwick  sedgwick-robert
# 0  Catharine Maria Sedgwick  sedgwick-robert
#
#                                           references  \
# 0  sedgwick-charles,sedgwick-elizabeth,sedgwick-h...
# 0  sedgwick-charles,sedgwick-elizabeth,sedgwick-h...
# 0  sedgwick-charles,sedgwick-elizabeth,sedgwick-h...
#
#                                                 text  wordCount
# 0  Albany March 8' 1819 -- I came dear Robert las...        200
# 0  worldly-mindedness -- I want much hear Jane ta...        200
# 0  hoping hear fate Doctor Osborne -- Poor Charlo...        165

# %% [markdown]
# ## Train Topic Model

# %%
# %%time

# Remove duplicate text rows (caused from unnesting headings) by subsetting & de-duplicating.
topics = df[['file', 'text']].drop_duplicates(subset = ['file'])

# Initialise the vectorizer with English stop words.
vectorizer = CountVectorizer(stop_words='english')

# Fit and transform the processed texts.
features = vectorizer.fit_transform(topics['text'])

# Helper function (from Kapadia).
def print_topics(model, vectorizer, n_top_words):
    words = vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))

# Set parameters (topics set to number of unique subject headings found).
number_topics = 40
number_words = 10

# Create and fit the LDA model
lda = LDA(n_components = number_topics, n_jobs=-1)
lda.fit(features)

# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# little eliza dear confidence situation robert fatigue return welcome account
#
# Topic #1:
# mrs kindness character life fashion mind intercourse know heart good
#
# Topic #2:
# dear love charles robert harry little think know god morning
#
# Topic #3:
# dear letter robert time shall know brother charles spirits dwight
#
# Topic #4:
# dear heart heaven robert judge mrs duty friends virtue harry
#
# Topic #5:
# dear think home time uncle beleive letter received class returned
#
# Topic #6:
# dear father love little confess school apprehensions affectionate absence boys
#
# Topic #7:
# time frances dear afflicted measure blessed god today uncle doctor
#
# Topic #8:
# like little dear sister thought hudson sweet shall tedious long
#
# Topic #9:
# dear charles heaven happiness little time francis best know bob
#
# Topic #10:
# little think theodore dear old letter say heart day sickness
#
# Topic #11:
# dear jane charles know harry feel sister think let brother
#
# Topic #12:
# wish subject good dear theodore opinion robert change blessed visit
#
# Topic #13:
# bed news watson better mr diminution folly fingers die annually
#
# Topic #14:
# dear robert mother uncle hudson letter days patience virtue things
#
# Topic #15:
# dear know think truth left feel kindness human letter shall
#
# Topic #16:
# dear better susan feel evening tell brother robert face jane
#
# Topic #17:
# être exchange executing execrable excuse excursions excursion exclusively excluded exclude
#
# Topic #18:
# dear mr time sister brother think desirous god stockbridge feelings
#
# Topic #19:
# papa heavenly mr repose expectation tuesday closed letter mercy entirely
#
# Topic #20:
# dear shall long letter week robert think received frances today
#
# Topic #21:
# être exchange executing execrable excuse excursions excursion exclusively excluded exclude
#
# Topic #22:
# dear harry letter like arrived know sin think foot says
#
# Topic #23:
# sedgwick sister opinion frequently lose patricia shared youthful maria catharine
#
# Topic #24:
# dear letter received papa susan poor presume letters frances kind
#
# Topic #25:
# dear frances time robert mind mr feel watson danger sister
#
# Topic #26:
# dear words new frances year state sister little arrived fatigued
#
# Topic #27:
# dear letter life papa happiness shall charles robert like home
#
# Topic #28:
# être exchange executing execrable excuse excursions excursion exclusively excluded exclude
#
# Topic #29:
# dear mrs letter kind write time think stockbridge papa friends
#
# Topic #30:
# être exchange executing execrable excuse excursions excursion exclusively excluded exclude
#
# Topic #31:
# know dear heart sister love beleive think little fact present
#
# Topic #32:
# dear people met amory time mrs friends mr determined jane
#
# Topic #33:
# dear new gratitude letter great hope sweet received kind friend
#
# Topic #34:
# shall dear robert worst _____ jane like heart letter god
#
# Topic #35:
# dear robert mr letter know little charles shall sister particularly
#
# Topic #36:
# être exchange executing execrable excuse excursions excursion exclusively excluded exclude
#
# Topic #37:
# charles letter fault jane kind frances informing sister dear good
#
# Topic #38:
# dear brother robert left feel suffering think salvation wants know
#
# Topic #39:
# dear sister single light day faith mail hope owe blessing
# CPU times: user 394 ms, sys: 198 ms, total: 592 ms
# Wall time: 2.46 s

# %% [markdown]
# ## Save pyLDAvis

# %%
# %%time

p = pyLDAvis.sklearn.prepare(lda, features, vectorizer, mds='mmds')

pyLDAvis.save_html(p, abs_dir + "lab_space/projects/sedgwick/topics/sedgwick_topics-40_pyLDAvis.html")
# Out:
# CPU times: user 1.96 s, sys: 24.6 ms, total: 1.98 s
# Wall time: 3.27 s
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# /opt/anaconda3/lib/python3.8/site-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
